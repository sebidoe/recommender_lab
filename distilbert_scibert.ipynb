# %%
import os
import json
import pandas as pd
import numpy as np
from zipfile import ZipFile
import time

# Preprocessing imports
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import string
import re
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import TweetTokenizer

# Used to create the dense document vectors and Faiss index.
import torch
import transformers
import faiss

from sklearn.metrics.pairwise import euclidean_distances

# %% [markdown]
# Dataset -->  Collection of 31000+ paper meta data. Data contains all paper related to ML, CL, NER, AI and CV field publish between 1992 to 2018-Feb. (researches about computer science all around the world.)

# %%
df = pd.read_json("arxivData.json")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41000 entries, 0 to 40999
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   author   41000 non-null  object
#  1   day      41000 non-null  int64
#  2   id       41000 non-null  object
#  3   link     41000 non-null  object
#  4   month    41000 non-null  int64
#  5   summary  41000 non-null  object
#  6   tag      41000 non-null  object
#  7   title    41000 non-null  object
#  8   year     41000 non-null  int64
# dtypes: int64(3), object(6)
# memory usage: 2.8+ MB

# %% [markdown]
# **Preprocessing**

# %%
# List of stop words
add_stop = ['said', 'say', 'like']
stop_words = ENGLISH_STOP_WORDS.union(add_stop)

# List of punctuation
punc = list(set(string.punctuation))

# %%
# Splits words on white spaces (leaves contractions intact) and splits out
# trailing punctuation
def casual_tokenizer(text):
    tokenizer = TweetTokenizer()
    tokens = tokenizer.tokenize(text)
    return tokens


def process_text(text):
    text = casual_tokenizer(text)
    text = [each.lower() for each in text]
    text = [re.sub('[0-9]+', '', each) for each in text]
    #text = [expandContractions(each, c_re=c_re) for each in text]
    text = [SnowballStemmer('english').stem(each) for each in text]
    text = [w for w in text if w not in punc]
    text = [w for w in text if w not in stop_words]
    text = [each for each in text if len(each) > 1]
    text = [each for each in text if ' ' not in each]
    return str(" ".join(text))

# %%
# Funtion to remove duplicate words
def unique_words(text): 
    ulist = []
    [ulist.append(x) for x in text if x not in ulist]
    return ulist


def word_count(text):
    return len(str(text).split(' '))

# %%
# Helper function to create batches to iterate over
def batch(data, batch_size):
    length = len(data)
    for i in range(0, length, batch_size):
        yield data[i:min(i + batch_size, length)]

# %%
# apply preprocessing
df['processed_text'] = df['summary'].apply(process_text)

# %%
df['summary'] = df['summary'].str.slice(0, 512)
df['processed_text'] = df['processed_text'].str.slice(0, 512)
df = df.dropna()

# %% [markdown]
# ### **DistilBert and SciBert**

# %%
DISTILBERT = 'distilbert-base-uncased'
SCIBERT = 'allenai/scibert_scivocab_uncased'

#load the models
disbert_model = transformers.AutoModel.from_pretrained(DISTILBERT)
scibert_model = transformers.AutoModel.from_pretrained(SCIBERT)
disbert_model.eval()
scibert_model.eval()

#create a transformer tokenizer for BERT using both models
disbert_tokenizer = transformers.AutoTokenizer.from_pretrained(DISTILBERT)
scibert_tokenizer = transformers.AutoTokenizer.from_pretrained(SCIBERT)

# use the cuda if one is available
if torch.cuda.is_available():
  disbert_model = disbert_model.to(torch.device("cuda"))
  scibert_model = scibert_model.to(torch.device("cuda"))

print(disbert_model.device)
print(scibert_model.device)
# Out:
# cuda:0
# cuda:0

# %%
def get_embeddings(model, tokenizer, data):
    embeddings = []
    for ba in batch(data, 1000):
        # tokenize the summaries and load it to the cuda
        tokenized = tokenizer(ba, padding=True, truncation=True, max_length=512, return_tensors="pt")

        if torch.cuda.is_available():
          tokenized = tokenized.to(torch.device("cuda"))

        # classify the text with the model
        with torch.no_grad():
           output = model(**tokenized)

        # extract the embeddings from the last layer of the model
        for item in output[0]:
          embeddings.append(item[0,:].cpu().detach().numpy())
    return embeddings

# %%
def get_embedding(model, tokenizer, text):
    # tokenize the summaries and load it to the cuda
    tokenized = tokenizer(text, padding=True, truncation=True, max_length=512, return_tensors="pt")

    if torch.cuda.is_available():
      tokenized = tokenized.to(torch.device("cuda"))

    # classify the text with the model
    with torch.no_grad():
       output = model(**tokenized)
    # extract the embeddings from the last layer of the model
    return output[0][0][0,:].cpu().detach().numpy().reshape(1, 768)

# %%
df['disbert_embeddings'] = get_embeddings(disbert_model, disbert_tokenizer, df['summary'].to_list())

# %%
df['scibert_embeddings'] = get_embeddings(scibert_model, scibert_tokenizer, df['summary'].to_list())

# %%
df['disbert_embeddings_pre'] = get_embeddings(disbert_model, disbert_tokenizer, df['processed_text'].to_list())

# %%
df['scibert_embeddings_pre'] = get_embeddings(scibert_model, scibert_tokenizer, df['processed_text'].to_list())

# %% [markdown]
# **Faiss**

# %%
def create_faiss_index(embeddings):
    # change the datatype of the embeddings
    embeddings = np.array(embeddings).astype("float32")
    # Initialize the index with the correct dimensions
    index = faiss.IndexFlatL2(embeddings.shape[1])
    # Add embeddings to the faiss index
    index.add(embeddings)
    print(f"Number of vectors in the Faiss index: {index.ntotal}")
    return index

# %%
def do_top_k_search(embeddings, query_text, model, tokenizer, top_k, verbose=True):
    #Compute Embedding of query text
    embedding_q = get_embedding(model, tokenizer, query_text)
    
    #Search and time of process
    st = time.time()
    distances = []
    for em in embeddings:
        
        em = np.expand_dims(em, axis = 0)
        distances.append(euclidean_distances(em, embedding_q)[0][0])
        
    top_k_arguments = np.argsort(np.array(distances))[:top_k]
    dis = np.array(distances)
    et = time.time()
    if verbose:
        print(f'L2 distance: {dis[top_k_arguments].tolist()}\n\nPaper Indexes: {top_k_arguments.tolist()}')
    return et - st, top_k_arguments

# %%
def do_faiss_search(index, model, tokenizer, query_text, k, verbose=True):
    # Retrieve the 10 nearest neighbours
    # D = distance, I= index
    st = time.time()
    D, I = index.search(get_embedding(model, tokenizer, query_text), k=k)
    et = time.time()
    if verbose:
        print(f'L2 distance: {D.flatten().tolist()}\n\nPaper indexes: {I.flatten().tolist()}')
    return et - st, I

# %%
disbert_index = create_faiss_index(df['disbert_embeddings'].to_list())
# Out:
# Number of vectors in the Faiss index: 41000

# %%
scibert_index = create_faiss_index(df['scibert_embeddings'].to_list())
# Out:
# Number of vectors in the Faiss index: 41000

# %%
disbert_pre_index = create_faiss_index(df['disbert_embeddings_pre'].to_list())
# Out:
# Number of vectors in the Faiss index: 41000

# %%
scibert_pre_index = create_faiss_index(df['scibert_embeddings_pre'].to_list())
# Out:
# Number of vectors in the Faiss index: 41000

# %%
sample_list = [9005, 25945, 25249, 13395, 1531, 31107, 1268, 18395, 36071, 13256]
models_tokenizer = [("disbert", disbert_model, disbert_tokenizer), ("scibert", scibert_model, scibert_tokenizer)]
embeddings = [[("no", disbert_index, df['disbert_embeddings'].to_list()), ("yes", disbert_pre_index, df['disbert_embeddings_pre'].to_list())], 
              [("no", scibert_index, df['scibert_embeddings'].to_list()), ("yes", scibert_pre_index, df['scibert_embeddings_pre'].to_list())]]

# %%
results_by_sample = {}
if len(models_tokenizer) == len(embeddings):
    for sample in sample_list:
        sample_results = {}
        for i, (model_name, model, tokenizer) in enumerate(models_tokenizer):
            pre_results = {}
            for preprocessing, index, embedding_list in embeddings[i]:
                
                faiss_time, I = do_faiss_search(index, model, tokenizer, df.iloc[sample].summary, 6, verbose=False)
                
                top_k_time, indexes_top = do_top_k_search(embedding_list, df.iloc[sample].summary, model, tokenizer, 6, verbose=False)
                
                pre_results[preprocessing] = {
                    "faiss": {
                        "query": sample,
                        "index": I,
                        "time": faiss_time
                    },
                    "top_k": {
                        "query": sample,
                        "index": indexes_top,
                        "time": top_k_time
                    }
                }
            sample_results[model_name] = pre_results
        results_by_sample[sample] = sample_results

# %%
def index2details(df, I, column="title", faiss=True):
    # Prints the paper titles based on the paper indexes.
    if faiss:
        I = I[0]
    for i, idx in enumerate(I):
        print("\t\t\t{}. {}".format(i, df.iloc[idx][column]))
    print()

# %%
faiss_avg_time = []
top_k_avg_time = []
for sample, sample_values in results_by_sample.items():
    print("\033[1mSample title: {}\033[0m".format(df.iloc[sample]["title"]))
    for model, model_values in sample_values.items():
        print("\033[1m\tModel:", model, "\033[0m")
        for preprocessing, preprocessing_values in model_values.items():
            print("\033[1m\t\tPreprocessing?", preprocessing, "\033[0m")
            
            faiss_avg_time.append(preprocessing_values["faiss"]["time"])
            top_k_avg_time.append(preprocessing_values["top_k"]["time"])
            
            if all(preprocessing_values["faiss"]["index"][0] == preprocessing_values["top_k"]["index"]):
                print("\033[1m\t\t\tFaiss and top k:", "\033[0m")
                index2details(df, preprocessing_values["faiss"]["index"])
            else:
                print("\033[1m\t\t\tFaiss:", "\033[0m")
                index2details(df, preprocessing_values["faiss"]["index"])
                print("\033[1m\t\t\tTop k:", "\033[0m")
                index2details(df, preprocessing_values["top_k"]["index"], faiss=False)
            

faiss_avg_time = sum(faiss_avg_time) / len(faiss_avg_time)
top_k_avg_time = sum(top_k_avg_time) / len(top_k_avg_time)

print("Faiss avg time:", faiss_avg_time)
print("Top k avg time:", top_k_avg_time)
# Out:
# Sample title: Temporal Topic Modeling to Assess Associations between News Trends and
#   Infectious Disease Outbreaks
# 	Model: disbert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Temporal Topic Modeling to Assess Associations between News Trends and
#   Infectious Disease Outbreaks
# 			1. Identifying Patterns of Associated-Conditions through Topic Models of
#   Electronic Medical Records
# 			2. NegBio: a high-performance tool for negation and uncertainty detection
#   in radiology reports
# 			3. Application of multiview techniques to NHANES dataset
# 			4. On the Ground Validation of Online Diagnosis with Twitter and Medical
#   Records
# 			5. Fast clustering for scalable statistical analysis on structured images
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. Fractionally Predictive Spiking Neurons
# 			1. Comment on "Biologically inspired protection of deep networks from
#   adversarial attacks"
# 			2. TrueLabel + Confusions: A Spectrum of Probabilistic Models in Analyzing
#   Multiple Ratings
# 			3. Cascading Denoising Auto-Encoder as a Deep Directed Generative Model
# 			4. Deep Attributes from Context-Aware Regional Neural Codes
# 			5. 3D Convolutional Encoder-Decoder Network for Low-Dose CT via Transfer
#   Learning from a 2D Trained Network
#
# 	Model: scibert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Temporal Topic Modeling to Assess Associations between News Trends and
#   Infectious Disease Outbreaks
# 			1. Personalization in Goal-Oriented Dialog
# 			2. Social Media Text Processing and Semantic Analysis for Smart Cities
# 			3. Learning Visual N-Grams from Web Data
# 			4. Identifying Interaction Sites in "Recalcitrant" Proteins: Predicted
#   Protein and Rna Binding Sites in Rev Proteins of Hiv-1 and Eiav Agree with
#   Experimental Data
# 			5. Generating Sentiment Lexicons for German Twitter
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. Quantifying Facial Age by Posterior of Age Comparisons
# 			1. Information Extraction from Broadcast News
# 			2. Sentiment Identification in Code-Mixed Social Media Text
# 			3. A Multi-Scale CNN and Curriculum Learning Strategy for Mammogram
#   Classification
# 			4. Characterizing Diabetes, Diet, Exercise, and Obesity Comments on Twitter
# 			5. Superpixel based Class-Semantic Texton Occurrences for Natural Roadside
#   Vegetation Segmentation
#
# Sample title: Seeing through the Human Reporting Bias: Visual Classifiers from Noisy
#   Human-Centric Labels
# 	Model: disbert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Seeing through the Human Reporting Bias: Visual Classifiers from Noisy
#   Human-Centric Labels
# 			1. Image Credibility Analysis with Effective Domain Transferred Deep
#   Networks
# 			2. Fine-grained Recognition in the Wild: A Multi-Task Domain Adaptation
#   Approach
# 			3. A deep architecture for unified aesthetic prediction
# 			4. Co-PACRR: A Context-Aware Neural IR Model for Ad-hoc Retrieval
# 			5. Modeling Loosely Annotated Images with Imagined Annotations
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. A Study on Topological Descriptors for the Analysis of 3D Surface
#   Texture
# 			1. Doubly-Attentive Decoder for Multi-modal Neural Machine Translation
# 			2. Max-Mahalanobis Linear Discriminant Analysis Networks
# 			3. Wide & Deep Learning for Recommender Systems
# 			4. Domain Knowledge Uncertainty and Probabilistic Parameter Constraints
# 			5. Where to Focus: Deep Attention-based Spatially Recurrent Bilinear
#   Networks for Fine-Grained Visual Recognition
#
# 	Model: scibert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Seeing through the Human Reporting Bias: Visual Classifiers from Noisy
#   Human-Centric Labels
# 			1. Towards a relation extraction framework for cyber-security concepts
# 			2. Improving Content-Invariance in Gated Autoencoders for 2D and 3D Object
#   Rotation
# 			3. Unsupervised Domain Adaptation by Backpropagation
# 			4. Authorship Attribution Using Word Network Features
# 			5. Zero-Shot Learning via Joint Latent Similarity Embedding
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. "I'm sorry Dave, I'm afraid I can't do that": Linguistics, Statistics,
#   and Natural Language Processing circa 2001
# 			1. HEp-2 Cell Classification: The Role of Gaussian Scale Space Theory as A
#   Pre-processing Approach
# 			2. Superpixel based Class-Semantic Texton Occurrences for Natural Roadside
#   Vegetation Segmentation
# 			3. Improvised Salient Object Detection and Manipulation
# 			4. Dialogue Act Segmentation for Vietnamese Human-Human Conversational
#   Texts
# 			5. Online Keyword Spotting with a Character-Level Recurrent Neural Network
#
# Sample title: Tell and Predict: Kernel Classifier Prediction for Unseen Visual Classes
#   from Unstructured Text Descriptions
# 	Model: disbert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Tell and Predict: Kernel Classifier Prediction for Unseen Visual Classes
#   from Unstructured Text Descriptions
# 			1. On Planning with Preferences in HTN
# 			2. Approximate Inference Algorithms for Hybrid Bayesian Networks with
#   Discrete Constraints
# 			3. Online Spatial Concept and Lexical Acquisition with Simultaneous
#   Localization and Mapping
# 			4. MPC-Inspired Neural Network Policies for Sequential Decision Making
# 			5. Probabilistic Zero-shot Classification with Semantic Rankings
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. Comparisons of Reasoning Mechanisms for Computer Vision
# 			1. Convolutional Neural Networks learn compact local image descriptors
# 			2. Two Projection Pursuit Algorithms for Machine Learning under
#   Non-Stationarity
# 			3. Discovering Cyclic Causal Models by Independent Components Analysis
# 			4. The Optimality of Satisficing Solutions
# 			5. Neurocontrol methods review
#
# 	Model: scibert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Tell and Predict: Kernel Classifier Prediction for Unseen Visual Classes
#   from Unstructured Text Descriptions
# 			1. Robust Unsupervised Domain Adaptation for Neural Networks via Moment
#   Alignment
# 			2. A Random Walk Based Model Incorporating Social Information for
#   Recommendations
# 			3. End-to-End Neural Ad-hoc Ranking with Kernel Pooling
# 			4. Non-Uniform Blind Deblurring with a Spatially-Adaptive Sparse Prior
# 			5. Principal motion components for gesture recognition using a
#   single-example
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. Inside-Outside Net: Detecting Objects in Context with Skip Pooling and
#   Recurrent Neural Networks
# 			1. Robust Actor-Critic Contextual Bandit for Mobile Health (mHealth)
#   Interventions
# 			2. Learning an Invariant Hilbert Space for Domain Adaptation
# 			3. Integrating Three Mechanisms of Visual Attention for Active Visual
#   Search
# 			4. A deep level set method for image segmentation
# 			5. An ILP Solver for Multi-label MRFs with Connectivity Constraints
#
# Sample title: Production System Rules as Protein Complexes from Genetic Regulatory
#   Networks
# 	Model: disbert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Production System Rules as Protein Complexes from Genetic Regulatory
#   Networks
# 			1. Higher-Order Quantum-Inspired Genetic Algorithms
# 			2. Emergent Network Structure, evolvable Robustness and non-linear Effects
#   of Point Mutations in an Artificial Genome Model
# 			3. Neural Generative Question Answering
# 			4. A Cumulative Multi-Niching Genetic Algorithm for Multimodal Function
#   Optimization
# 			5. From Cells to Islands: An unified Model of Cellular Parallel Genetic
#   Algorithms
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. Comment on "Biologically inspired protection of deep networks from
#   adversarial attacks"
# 			1. Neurocontrol methods review
# 			2. Convolutional Neural Networks learn compact local image descriptors
# 			3. Tensor2Tensor for Neural Machine Translation
# 			4. On the Latent Space of Wasserstein Auto-Encoders
# 			5. TrueLabel + Confusions: A Spectrum of Probabilistic Models in Analyzing
#   Multiple Ratings
#
# 	Model: scibert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Production System Rules as Protein Complexes from Genetic Regulatory
#   Networks
# 			1. A Foundation to Perception Computing, Logic and Automata
# 			2. Evolutionary Design of Digital Circuits Using Genetic Programming
# 			3. Learning Polynomial Networks for Classification of Clinical
#   Electroencephalograms
# 			4. Bootstrapping incremental dialogue systems from minimal data: the
#   generalisation power of dialogue grammars
# 			5. Fundamentals of Mathematical Theory of Emotional Robots
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. "I'm sorry Dave, I'm afraid I can't do that": Linguistics, Statistics,
#   and Natural Language Processing circa 2001
# 			1. A Heuristic Search Algorithm Using the Stability of Learning Algorithms
#   in Certain Scenarios as the Fitness Function: An Artificial General
#   Intelligence Engineering Approach
# 			2. Prefix Probabilities from Stochastic Tree Adjoining Grammars
# 			3. Online Convex Optimization for Cumulative Constraints
# 			4. Investigation of commuting Hamiltonian in quantum Markov network
# 			5. Efficiency Enhancement of Genetic Algorithms via Building-Block-Wise
#   Fitness Estimation
#
# Sample title: Inducing a Semantically Annotated Lexicon via EM-Based Clustering
# 	Model: disbert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Inducing a Semantically Annotated Lexicon via EM-Based Clustering
# 			1. Variational Inference of Disentangled Latent Concepts from Unlabeled
#   Observations
# 			2. Context models on sequences of covers
# 			3. NPGLM: A Non-Parametric Method for Temporal Link Prediction
# 			4. A Structured Variational Auto-encoder for Learning Deep Hierarchies of
#   Sparse Features
# 			5. Manifold Relevance Determination
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. From Ordinary Differential Equations to Structural Causal Models: the
#   deterministic case
# 			1. A TCSP-like decidable constraint language generalising existing cardinal
#   direction relations
# 			2. State Compression of Markov Processes via Empirical Low-Rank Estimation
# 			3. Comparisons of Reasoning Mechanisms for Computer Vision
# 			4. Robustness of classifiers to uniform $\ell\_p$ and Gaussian noise
# 			5. A Note on Tight Lower Bound for MNL-Bandit Assortment Selection Models
#
# 	Model: scibert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Inducing a Semantically Annotated Lexicon via EM-Based Clustering
# 			1. Virtual View Networks for Object Reconstruction
# 			2. Distributed Revision of Belief Commitment in Multi-Hypothesis
#   Interpretations
# 			3. Utility-Based Abstraction and Categorization
# 			4. As you like it: Localization via paired comparisons
# 			5. Discriminatory Transfer
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. "I'm sorry Dave, I'm afraid I can't do that": Linguistics, Statistics,
#   and Natural Language Processing circa 2001
# 			1. The Grail theorem prover: Type theory for syntax and semantics
# 			2. Yin and Yang: Balancing and Answering Binary Visual Questions
# 			3. Efficient Fruit Defect Detection and Glare removal Algorithm by
#   anisotropic diffusion and 2D Gabor filter
# 			4. An ILP Solver for Multi-label MRFs with Connectivity Constraints
# 			5. Bidirectional Beam Search: Forward-Backward Inference in Neural Sequence
#   Models for Fill-in-the-Blank Image Captioning
#
# Sample title: On-device Scalable Image-based Localization
# 	Model: disbert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. On-device Scalable Image-based Localization
# 			1. DimensionApp : android app to estimate object dimensions
# 			2. Inertial Odometry on Handheld Smartphones
# 			3. Towards Multi-Object Detection and Tracking in Urban Scenario under
#   Uncertainties
# 			4. A Dataset for Developing and Benchmarking Active Vision
# 			5. Geometry-Based Region Proposals for Real-Time Robot Detection of
#   Tabletop Objects
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. Motion Segmentation by SCC on the Hopkins 155 Database
# 			1. Technical Report: Implementation and Validation of a Smart Health
#   Application
# 			2. Improving sentence compression by learning to predict gaze
# 			3. Limbo: A Fast and Flexible Library for Bayesian Optimization
# 			4. Virtual Worlds as Proxy for Multi-Object Tracking Analysis
# 			5. GPU-based Pedestrian Detection for Autonomous Driving
#
# 	Model: scibert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. On-device Scalable Image-based Localization
# 			1. Wide-Area Image Geolocalization with Aerial Reference Imagery
# 			2. Distributed Deep Reinforcement Learning: Learn how to play Atari games
#   in 21 minutes
# 			3. In-Place Activated BatchNorm for Memory-Optimized Training of DNNs
# 			4. Towards a Cognitive Routing Engine for Software Defined Networks
# 			5. Improving Video Generation for Multi-functional Applications
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. 3D Shape Segmentation with Projective Convolutional Networks
# 			1. SSH: Single Stage Headless Face Detector
# 			2. "I'm sorry Dave, I'm afraid I can't do that": Linguistics, Statistics,
#   and Natural Language Processing circa 2001
# 			3. Application of a semantic segmentation convolutional neural network for
#   accurate automatic detection and mapping of solar photovoltaic arrays in
#   aerial imagery
# 			4. Boosting-like Deep Learning For Pedestrian Detection
# 			5. DOC: Deep Open Classification of Text Documents
#
# Sample title: Dynamic Weight Alignment for Convolutional Neural Networks
# 	Model: disbert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Dynamic Weight Alignment for Convolutional Neural Networks
# 			1. Stochastic Configuration Networks: Fundamentals and Algorithms
# 			2. A Deep Learning Approach for Reconstruction Filter Kernel Discretization
# 			3. Multilinear Map Layer: Prediction Regularization by Structural
#   Constraint
# 			4. Text Generation Based on Generative Adversarial Nets with Latent
#   Variable
# 			5. Deep Kernelized Autoencoders
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. Convolutional Neural Networks learn compact local image descriptors
# 			1. Tensor2Tensor for Neural Machine Translation
# 			2. Robustness of classifiers to uniform $\ell\_p$ and Gaussian noise
# 			3. Comparisons of Reasoning Mechanisms for Computer Vision
# 			4. A TCSP-like decidable constraint language generalising existing cardinal
#   direction relations
# 			5. Discovering Multiple Constraints that are Frequently Approximately
#   Satisfied
#
# 	Model: scibert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Dynamic Weight Alignment for Convolutional Neural Networks
# 			1. Training with Confusion for Fine-Grained Visual Classification
# 			2. Applying machine learning to the problem of choosing a heuristic to
#   select the variable ordering for cylindrical algebraic decomposition
# 			3. A kernel for time series based on global alignments
# 			4. Class-specific Poisson denoising by patch-based importance sampling
# 			5. Large-scale Feature Selection of Risk Genetic Factors for Alzheimer's
#   Disease via Distributed Group Lasso Regression
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. Learned Features are better for Ethnicity Classification
# 			1. Hand Tracking based on Hierarchical Clustering of Range Data
# 			2. A textual transform of multivariate time-series for prognostics
# 			3. Learning an Invariant Hilbert Space for Domain Adaptation
# 			4. Hidden Two-Stream Convolutional Networks for Action Recognition
# 			5. FAASTA: A fast solver for total-variation regularization of
#   ill-conditioned problems with application to brain imaging
#
# Sample title: Decision Support Systems (DSS) in Construction Tendering Processes
# 	Model: disbert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Decision Support Systems (DSS) in Construction Tendering Processes
# 			1. A Multi-Stage Supply Chain Network Optimization Using Genetic Algorithms
# 			2. Proficiency Comparison of LADTree and REPTree Classifiers for Credit
#   Risk Forecast
# 			3. Relevant Knowledge First - Reinforcement Learning and Forgetting in
#   Knowledge Based Configuration
# 			4. Data Mining for Prediction of Human Performance Capability in the
#   Software-Industry
# 			5. Knowledge management for enterprises (Wissensmanagement fuer
#   Unternehmen)
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. Rational Competitive Analysis
# 			1. A Market-Oriented Programming Environment and its Application to
#   Distributed Multicommodity Flow Problems
# 			2. A multi-agent reinforcement learning model of common-pool resource
#   appropriation
# 			3. Responsible Autonomy
# 			4. Artificial Agents and Speculative Bubbles
# 			5. Cost and Actual Causation
#
# 	Model: scibert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Decision Support Systems (DSS) in Construction Tendering Processes
# 			1. Incremental Minimax Optimization based Fuzzy Clustering for Large
#   Multi-view Data
# 			2. Scalable Audience Reach Estimation in Real-time Online Advertising
# 			3. The Indian Spontaneous Expression Database for Emotion Recognition
# 			4. A Comparison Between Data Mining Prediction Algorithms for Fault
#   Detection(Case study: Ahanpishegan co.)
# 			5. Dyna-H: a heuristic planning reinforcement learning algorithm applied to
#   role-playing-game strategy decision systems
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. DGT-TM: A freely Available Translation Memory in 22 Languages
# 			1. "I'm sorry Dave, I'm afraid I can't do that": Linguistics, Statistics,
#   and Natural Language Processing circa 2001
# 			2. Robust Actor-Critic Contextual Bandit for Mobile Health (mHealth)
#   Interventions
# 			3. An ILP Solver for Multi-label MRFs with Connectivity Constraints
# 			4. Biologically inspired design framework for Robot in Dynamic Environments
#   using Framsticks
# 			5. Hindi to English Transfer Based Machine Translation System
#
# Sample title: Efficient MRF Energy Minimization via Adaptive Diminishing Smoothing
# 	Model: disbert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Efficient MRF Energy Minimization via Adaptive Diminishing Smoothing
# 			1. Zero-Temperature Limit of a Convergent Algorithm to Minimize the Bethe
#   Free Energy
# 			2. Robust Subspace Clustering via Smoothed Rank Approximation
# 			3. On the Maximum Entropy Property of the First-Order Stable Spline Kernel
#   and its Implications
# 			4. KL-learning: Online solution of Kullback-Leibler control problems
# 			5. Dropout as a Low-Rank Regularizer for Matrix Factorization
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. Competing with Gaussian linear experts
# 			1. A Note on Tight Lower Bound for MNL-Bandit Assortment Selection Models
# 			2. Gradient Descent Converges to Minimizers
# 			3. Fast Sampling for Strongly Rayleigh Measures with Application to
#   Determinantal Point Processes
# 			4. Manifold estimation and singular deconvolution under Hausdorff loss
# 			5. A TCSP-like decidable constraint language generalising existing cardinal
#   direction relations
#
# 	Model: scibert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Efficient MRF Energy Minimization via Adaptive Diminishing Smoothing
# 			1. High-dimensional Black-box Optimization via Divide and Approximate
#   Conquer
# 			2. Automatic Spatially-Adaptive Balancing of Energy Terms for Image
#   Segmentation
# 			3. Manifold Learning with Geodesic Minimal Spanning Trees
# 			4. Unifying Local and Global Change Detection in Dynamic Networks
# 			5. Reinforced Decision Trees
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. A textual transform of multivariate time-series for prognostics
# 			1. FAASTA: A fast solver for total-variation regularization of
#   ill-conditioned problems with application to brain imaging
# 			2. GOGMA: Globally-Optimal Gaussian Mixture Alignment
# 			3. Bayes-Optimal Effort Allocation in Crowdsourcing: Bounds and Index
#   Policies
# 			4. Natasha 2: Faster Non-Convex Optimization Than SGD
# 			5. Evaluating the visualization of what a Deep Neural Network has learned
#
# Sample title: Obtaining Membership Functions from a Neuron Fuzzy System extended by
#   Kohonen Network
# 	Model: disbert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Obtaining Membership Functions from a Neuron Fuzzy System extended by
#   Kohonen Network
# 			1. A Neuro-Fuzzy Technique for Implementing the Half-Adder Circuit Using
#   the CANFIS Model
# 			2. An Experimental Analysis of the Echo State Network Initialization Using
#   the Particle Swarm Optimization
# 			3. Bayesian Neural Networks
# 			4. Analysis of hydrocyclone performance based on information granulation
#   theory
# 			5. On the Resilience of an Ant-based System in Fuzzy Environments. An
#   Empirical Study
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. Comparisons of Reasoning Mechanisms for Computer Vision
# 			1. Tensor2Tensor for Neural Machine Translation
# 			2. Convolutional Neural Networks learn compact local image descriptors
# 			3. A TCSP-like decidable constraint language generalising existing cardinal
#   direction relations
# 			4. Neurocontrol methods review
# 			5. The Optimality of Satisficing Solutions
#
# 	Model: scibert
# 		Preprocessing? no
# 			Faiss and top k:
# 			0. Obtaining Membership Functions from a Neuron Fuzzy System extended by
#   Kohonen Network
# 			1. Back analysis of microplane model parameters using soft computing
#   methods
# 			2. Neural Network Influence in Group Technology: A Chronological Survey and
#   Critical Analysis
# 			3. Control Neuronal por Modelo Inverso de un Servosistema Usando Algoritmos
#   de Aprendizaje Levenberg-Marquardt y Bayesiano
# 			4. Application of Rough Set Theory to Analysis of Hydrocyclone Operation
# 			5. Improvement of BM3D Algorithm and Employment to Satellite and CFA Images
#   Denoising
#
# 		Preprocessing? yes
# 			Faiss and top k:
# 			0. Speckle Reduction using Stochastic Distances
# 			1. Decision Principles to justify Carnap's Updating Method and to Suggest
#   Corrections of Probability Judgments (Invited Talks)
# 			2. A New Algorithm of Speckle Filtering using Stochastic Distances
# 			3. Monte Carlo Action Programming
# 			4. Efficient Stepwise Selection in Decomposable Models
# 			5. A Heuristic Search Algorithm Using the Stability of Learning Algorithms
#   in Certain Scenarios as the Fitness Function: An Artificial General
#   Intelligence Engineering Approach
#
# Faiss avg time: 0.07878460884094238
# Top k avg time: 5.92924023270607
